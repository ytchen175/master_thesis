# %%
import pandas as pd

df = pd.read_excel("./corpus/_正體(繁體)/教育部_成語典.xlsx")
df
# Out:
#         字詞名         字詞號 部首字  總筆畫數  部首外筆畫數  多音排序               注音一式  \
# 0         八        0001  八      2       0     0                 ㄅㄚ
# 1      八拜之交   000100000  八      2       0     0       ㄅㄚ　ㄅㄞˋ　ㄓ　ㄐㄧㄠ
# 2       八寶飯  0001000001  八      2       0     0         ㄅㄚ　ㄅㄠˇ　ㄈㄢˋ
# 3       八寶粥   000100001  八      2       0     0          ㄅㄚ　ㄅㄠˇ　ㄓㄡ
# 4      八面玲瓏   000100002  八      2       0     0  ㄅㄚ　ㄇㄧㄢˋ　ㄌㄧㄥˊ　ㄌㄨㄥˊ
# ...     ...         ...  ..   ...     ...   ...                ...
# 45222   名人堂  0770000411  口      6       3     0       ㄇㄧㄥˊ　ㄖㄣˊ　ㄊㄤˊ
# 45223   開胃菜  2521001081  門     12       4     0         ㄎㄞ　ㄨㄟˋ　ㄘㄞˋ
# 45224    甜湯  1479000051  甘     11       6     0            ㄊㄧㄢˊ　ㄊㄤ
# 45225   指示圖  4256000340  手      9       6     0          ㄓˇ　ㄕˋ　ㄊㄨˊ
# 45226    來年  1757000090  人      8       6     0           ㄌㄞˊ　ㄋㄧㄢˊ
#
#       變體類型 1:變 2:又音 3:語音 4:讀音 變體注音               漢語拼音 變體漢語拼音  相似詞  相反詞  \
# 0                              NaN                 bā    NaN  NaN  NaN
# ...
